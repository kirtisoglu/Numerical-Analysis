# %%
import pandas as pd 

data = pd.read_excel("population-change.xlsx")
data.head()
# Out:
#                          U.S. Department of Commerce  \
# 0                                 U.S. Census Bureau
# 1  Change in Resident Population of the 50 States...
# 2                                               Area
# 3                                                NaN
# 4                                            Alabama
#
#                         Unnamed: 1                  Unnamed: 2  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                      2020 Census                         NaN
# 3  Resident Population 2020 Census  Percent Change 2020 Census
# 4                          5024279                         5.1
#
#                         Unnamed: 3                  Unnamed: 4  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                      2010 Census                         NaN
# ...
